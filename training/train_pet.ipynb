# %%
import os
import random
import tensorflow as tf
from tensorflow import keras
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import pickle5 as pickle
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
from tensorflow.keras.layers import Dense,Dropout,MaxPooling2D, Flatten, Conv2D

# %%
with open("pet_train/pet_train.pkl", "rb") as fh:
    data = pickle.load(fh)
X_train_ = pd.DataFrame(data)["img_array"] 

with open("pet_train/pet_test.pkl", "rb") as fh:
    data = pickle.load(fh)
X_test_ = pd.DataFrame(data)["img_array"]

with open("pet_train/pet_y_train.pkl", "rb") as fh:
    data = pickle.load(fh)
y_train = np.array(pd.DataFrame(data)["label"].values.astype(np.float32)).flatten()

with open("pet_train/pet_y_test.pkl", "rb") as fh:
    data = pickle.load(fh)
y_test = np.array(pd.DataFrame(data)["label"].values.astype(np.float32)).flatten()

# %%
def train():
    y_test[y_test == 2] = -1
    y_test[y_test == 1] = 2
    y_test[y_test == -1] = 1
    
    y_train[y_train == 2] = -1
    y_train[y_train == 1] = 2
    y_train[y_train == -1] = 1
    

    X_train = []
    X_test = []
    
    for i in range(len(X_train_)):
        X_train.append(X_train_.values[i])
        
    for i in range(len(X_test_)):
        X_test.append(X_test_.values[i])
    
    
    X_train = np.array(X_train)
    X_test = np.array(X_test)


    # (3909, 1, 72, 72, 3) //original shape
    X_train= X_train.reshape(-1,72,72,3)
    #modified shape (3909,72, 72, 3)

    # (205, 1, 72, 72, 3) //original shape
    X_test= X_test.reshape(-1,72,72,3)
    #modified shape (205,72, 72, 3)


    model = Sequential()
    model.add(Conv2D(100, (3, 3),  activation='relu', input_shape=(72, 72, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.5))
    model.add(Conv2D(50, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))
    model.add(Flatten())
    model.add(Dense(3, activation = "softmax"))
    
    
    model.compile(Adam(learning_rate = 0.001), "sparse_categorical_crossentropy", metrics = ["sparse_categorical_accuracy"])
    
    model.summary()
    

    history = model.fit(X_train, y_train, epochs=50, batch_size=32 ,validation_split=0.1, verbose=1) 

    model.save("./saved_models/train_pet_model_base.hdf5")


    plt.clf()
    plt.plot(history.history['sparse_categorical_accuracy'])
    plt.plot(history.history['val_sparse_categorical_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    plt.clf()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    plt.clf()

# %%
train()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 70, 70, 100)       2800
#
#  max_pooling2d (MaxPooling2D  (None, 35, 35, 100)      0
#  )
#
#  dropout (Dropout)           (None, 35, 35, 100)       0
#
#  conv2d_1 (Conv2D)           (None, 33, 33, 50)        45050
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 50)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 50)        0
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 3)                 38403
#
# =================================================================
# Total params: 86,253
# Trainable params: 86,253
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 64/64 [==============================] - 24s 198ms/step - loss: 575.7684 - sparse_categorical_accuracy: 0.3733 - val_loss: 1.0945 - val_sparse_categorical_accuracy: 0.3744
# Epoch 2/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.9707 - sparse_categorical_accuracy: 0.3655 - val_loss: 1.0885 - val_sparse_categorical_accuracy: 0.3833
# Epoch 3/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.5829 - sparse_categorical_accuracy: 0.3645 - val_loss: 1.0820 - val_sparse_categorical_accuracy: 0.3965
# Epoch 4/50
# 64/64 [==============================] - 10s 159ms/step - loss: 1.5009 - sparse_categorical_accuracy: 0.3469 - val_loss: 1.0795 - val_sparse_categorical_accuracy: 0.3833
# Epoch 5/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.4101 - sparse_categorical_accuracy: 0.3572 - val_loss: 1.0763 - val_sparse_categorical_accuracy: 0.4185
# Epoch 6/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.2999 - sparse_categorical_accuracy: 0.3552 - val_loss: 1.0750 - val_sparse_categorical_accuracy: 0.4185
# Epoch 7/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.2474 - sparse_categorical_accuracy: 0.3449 - val_loss: 1.0737 - val_sparse_categorical_accuracy: 0.4229
# Epoch 8/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.1788 - sparse_categorical_accuracy: 0.3582 - val_loss: 1.0729 - val_sparse_categorical_accuracy: 0.4185
# Epoch 9/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.2071 - sparse_categorical_accuracy: 0.3684 - val_loss: 1.0727 - val_sparse_categorical_accuracy: 0.4229
# Epoch 10/50
# 64/64 [==============================] - 10s 157ms/step - loss: 1.1842 - sparse_categorical_accuracy: 0.3797 - val_loss: 1.0728 - val_sparse_categorical_accuracy: 0.3524
# Epoch 11/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.1283 - sparse_categorical_accuracy: 0.4307 - val_loss: 1.0731 - val_sparse_categorical_accuracy: 0.3480
# Epoch 12/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.2329 - sparse_categorical_accuracy: 0.4302 - val_loss: 1.0737 - val_sparse_categorical_accuracy: 0.3480
# Epoch 13/50
# 64/64 [==============================] - 10s 157ms/step - loss: 1.1179 - sparse_categorical_accuracy: 0.4238 - val_loss: 1.0739 - val_sparse_categorical_accuracy: 0.3480
# Epoch 14/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.1070 - sparse_categorical_accuracy: 0.4317 - val_loss: 1.0743 - val_sparse_categorical_accuracy: 0.3480
# Epoch 15/50
# 64/64 [==============================] - 10s 157ms/step - loss: 1.1012 - sparse_categorical_accuracy: 0.4405 - val_loss: 1.0748 - val_sparse_categorical_accuracy: 0.3480
# Epoch 16/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.1362 - sparse_categorical_accuracy: 0.4287 - val_loss: 1.0751 - val_sparse_categorical_accuracy: 0.3480
# Epoch 17/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.1000 - sparse_categorical_accuracy: 0.4321 - val_loss: 1.0754 - val_sparse_categorical_accuracy: 0.3480
# Epoch 18/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.1191 - sparse_categorical_accuracy: 0.4238 - val_loss: 1.0759 - val_sparse_categorical_accuracy: 0.3480
# Epoch 19/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0932 - sparse_categorical_accuracy: 0.4331 - val_loss: 1.0766 - val_sparse_categorical_accuracy: 0.3480
# Epoch 20/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0924 - sparse_categorical_accuracy: 0.4317 - val_loss: 1.0766 - val_sparse_categorical_accuracy: 0.3480
# Epoch 21/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0885 - sparse_categorical_accuracy: 0.4326 - val_loss: 1.0769 - val_sparse_categorical_accuracy: 0.3480
# Epoch 22/50
# 64/64 [==============================] - 10s 157ms/step - loss: 1.0992 - sparse_categorical_accuracy: 0.4253 - val_loss: 1.0771 - val_sparse_categorical_accuracy: 0.3480
# Epoch 23/50
# 64/64 [==============================] - 10s 157ms/step - loss: 1.0731 - sparse_categorical_accuracy: 0.4321 - val_loss: 1.0776 - val_sparse_categorical_accuracy: 0.3480
# Epoch 24/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.1199 - sparse_categorical_accuracy: 0.4380 - val_loss: 1.0784 - val_sparse_categorical_accuracy: 0.3524
# Epoch 25/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.1276 - sparse_categorical_accuracy: 0.4179 - val_loss: 1.0781 - val_sparse_categorical_accuracy: 0.3480
# Epoch 26/50
# 64/64 [==============================] - 10s 157ms/step - loss: 1.0773 - sparse_categorical_accuracy: 0.4380 - val_loss: 1.0782 - val_sparse_categorical_accuracy: 0.3480
# Epoch 27/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0726 - sparse_categorical_accuracy: 0.4356 - val_loss: 1.0783 - val_sparse_categorical_accuracy: 0.3480
# Epoch 28/50
# 64/64 [==============================] - 10s 157ms/step - loss: 1.0711 - sparse_categorical_accuracy: 0.4282 - val_loss: 1.0784 - val_sparse_categorical_accuracy: 0.3480
# Epoch 29/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0612 - sparse_categorical_accuracy: 0.4331 - val_loss: 1.0788 - val_sparse_categorical_accuracy: 0.3480
# Epoch 30/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0587 - sparse_categorical_accuracy: 0.4297 - val_loss: 1.0793 - val_sparse_categorical_accuracy: 0.3480
# Epoch 31/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0652 - sparse_categorical_accuracy: 0.4449 - val_loss: 1.0791 - val_sparse_categorical_accuracy: 0.3480
# Epoch 32/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0653 - sparse_categorical_accuracy: 0.4346 - val_loss: 1.0791 - val_sparse_categorical_accuracy: 0.3480
# Epoch 33/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0596 - sparse_categorical_accuracy: 0.4346 - val_loss: 1.0790 - val_sparse_categorical_accuracy: 0.3480
# Epoch 34/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0630 - sparse_categorical_accuracy: 0.4405 - val_loss: 1.0792 - val_sparse_categorical_accuracy: 0.3524
# Epoch 35/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0631 - sparse_categorical_accuracy: 0.4361 - val_loss: 1.0790 - val_sparse_categorical_accuracy: 0.3480
# Epoch 36/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0739 - sparse_categorical_accuracy: 0.4341 - val_loss: 1.0783 - val_sparse_categorical_accuracy: 0.3480
# Epoch 37/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0625 - sparse_categorical_accuracy: 0.4390 - val_loss: 1.0786 - val_sparse_categorical_accuracy: 0.3524
# Epoch 38/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0613 - sparse_categorical_accuracy: 0.4419 - val_loss: 1.0793 - val_sparse_categorical_accuracy: 0.3480
# Epoch 39/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0497 - sparse_categorical_accuracy: 0.4390 - val_loss: 1.0786 - val_sparse_categorical_accuracy: 0.3480
# Epoch 40/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0646 - sparse_categorical_accuracy: 0.4405 - val_loss: 1.0753 - val_sparse_categorical_accuracy: 0.3480
# Epoch 41/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0453 - sparse_categorical_accuracy: 0.4395 - val_loss: 1.0730 - val_sparse_categorical_accuracy: 0.3524
# Epoch 42/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0642 - sparse_categorical_accuracy: 0.4483 - val_loss: 1.0692 - val_sparse_categorical_accuracy: 0.3789
# Epoch 43/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0461 - sparse_categorical_accuracy: 0.4512 - val_loss: 1.0664 - val_sparse_categorical_accuracy: 0.3833
# Epoch 44/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0349 - sparse_categorical_accuracy: 0.4576 - val_loss: 1.0636 - val_sparse_categorical_accuracy: 0.3833
# Epoch 45/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0393 - sparse_categorical_accuracy: 0.4596 - val_loss: 1.0608 - val_sparse_categorical_accuracy: 0.3921
# Epoch 46/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0506 - sparse_categorical_accuracy: 0.4493 - val_loss: 1.0535 - val_sparse_categorical_accuracy: 0.4053
# Epoch 47/50
# 64/64 [==============================] - 10s 157ms/step - loss: 1.0454 - sparse_categorical_accuracy: 0.4625 - val_loss: 1.0566 - val_sparse_categorical_accuracy: 0.3965
# Epoch 48/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0460 - sparse_categorical_accuracy: 0.4478 - val_loss: 1.0524 - val_sparse_categorical_accuracy: 0.4053
# Epoch 49/50
# 64/64 [==============================] - 10s 156ms/step - loss: 1.0287 - sparse_categorical_accuracy: 0.4674 - val_loss: 1.0505 - val_sparse_categorical_accuracy: 0.4009
# Epoch 50/50
# 64/64 [==============================] - 10s 157ms/step - loss: 1.0351 - sparse_categorical_accuracy: 0.4591 - val_loss: 1.0631 - val_sparse_categorical_accuracy: 0.3744
